# %% [markdown]
# # Read and clean Data

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('archive//CarPrice_Assignment.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
# check for nan
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#check for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Variables

# %% [markdown]
# ### price

# %%
df.price.describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
sns.distplot(df['price'])
# Out:
# /var/folders/d0/pgthqjbn0b7cqb1j8c6yxtlr0000gn/T/ipykernel_1245/444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ### symboling

# %% [markdown]
# Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.(Categorical)

# %%
df.symboling.value_counts()
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64

# %%
df.groupby("symboling")["price"].mean()
# Out:
# symboling
# -2    15781.666667
# -1    17330.681818
#  0    14366.965179
#  1    10037.907407
#  2    10109.281250
#  3    17221.296296
# Name: price, dtype: float64

# %% [markdown]
# ### Car Brand

# %%
df.CarName
# Out:
# 0                   alfa-romero giulia
# 1                  alfa-romero stelvio
# 2             alfa-romero Quadrifoglio
# 3                          audi 100 ls
# 4                           audi 100ls
# 5                             audi fox
# 6                           audi 100ls
# 7                            audi 5000
# 8                            audi 4000
# 9                  audi 5000s (diesel)
# 10                            bmw 320i
# 11                            bmw 320i
# 12                              bmw x1
# 13                              bmw x3
# 14                              bmw z4
# 15                              bmw x4
# 16                              bmw x5
# 17                              bmw x3
# 18                    chevrolet impala
# 19               chevrolet monte carlo
# 20                 chevrolet vega 2300
# 21                       dodge rampage
# 22                 dodge challenger se
# 23                          dodge d200
# 24                   dodge monaco (sw)
# 25                  dodge colt hardtop
# 26                     dodge colt (sw)
# 27                dodge coronet custom
# 28                   dodge dart custom
# 29           dodge coronet custom (sw)
# 30                         honda civic
# 31                    honda civic cvcc
# 32                         honda civic
# 33                   honda accord cvcc
# 34                    honda civic cvcc
# 35                     honda accord lx
# 36                 honda civic 1500 gl
# 37                        honda accord
# 38                    honda civic 1300
# 39                       honda prelude
# 40                        honda accord
# 41                         honda civic
# 42                  honda civic (auto)
# 43                          isuzu MU-X
# 44                        isuzu D-Max
# 45                 isuzu D-Max V-Cross
# 46                        isuzu D-Max
# 47                           jaguar xj
# 48                           jaguar xf
# 49                           jaguar xk
# 50                           maxda rx3
# 51                    maxda glc deluxe
# 52                     mazda rx2 coupe
# 53                          mazda rx-4
# 54                    mazda glc deluxe
# 55                           mazda 626
# 56                           mazda glc
# 57                       mazda rx-7 gs
# 58                         mazda glc 4
# 59                           mazda 626
# 60                  mazda glc custom l
# 61                    mazda glc custom
# 62                          mazda rx-4
# 63                    mazda glc deluxe
# 64                           mazda 626
# 65                           mazda glc
# 66                       mazda rx-7 gs
# 67            buick electra 225 custom
# 68            buick century luxus (sw)
# 69                       buick century
# 70                       buick skyhawk
# 71             buick opel isuzu deluxe
# 72                       buick skylark
# 73               buick century special
# 74     buick regal sport coupe (turbo)
# 75                      mercury cougar
# 76                   mitsubishi mirage
# 77                   mitsubishi lancer
# 78                mitsubishi outlander
# 79                       mitsubishi g4
# 80                mitsubishi mirage g4
# 81                       mitsubishi g4
# 82                mitsubishi outlander
# 83                       mitsubishi g4
# 84                mitsubishi mirage g4
# 85                  mitsubishi montero
# 86                   mitsubishi pajero
# 87                mitsubishi outlander
# 88                mitsubishi mirage g4
# 89                        Nissan versa
# 90                         nissan gt-r
# 91                        nissan rogue
# 92                        nissan latio
# 93                        nissan titan
# 94                         nissan leaf
# 95                         nissan juke
# 96                        nissan latio
# 97                         nissan note
# 98                      nissan clipper
# 99                        nissan rogue
# 100                       nissan nv200
# 101                        nissan dayz
# 102                        nissan fuga
# 103                        nissan otti
# 104                       nissan teana
# 105                       nissan kicks
# 106                     nissan clipper
# 107                        peugeot 504
# 108                        peugeot 304
# 109                   peugeot 504 (sw)
# 110                        peugeot 504
# 111                        peugeot 504
# 112                      peugeot 604sl
# 113                        peugeot 504
# 114          peugeot 505s turbo diesel
# 115                        peugeot 504
# 116                        peugeot 504
# 117                      peugeot 604sl
# 118                  plymouth fury iii
# 119                   plymouth cricket
# 120                  plymouth fury iii
# 121     plymouth satellite custom (sw)
# 122           plymouth fury gran sedan
# 123                   plymouth valiant
# 124                    plymouth duster
# 125                      porsche macan
# 126                  porcshce panamera
# 127                    porsche cayenne
# 128                     porsche boxter
# 129                    porsche cayenne
# 130                       renault 12tl
# 131                      renault 5 gtl
# 132                           saab 99e
# 133                          saab 99le
# 134                          saab 99le
# 135                         saab 99gle
# 136                         saab 99gle
# 137                           saab 99e
# 138                             subaru
# 139                          subaru dl
# 140                          subaru dl
# 141                             subaru
# 142                         subaru brz
# 143                        subaru baja
# 144                          subaru r1
# 145                          subaru r2
# 146                      subaru trezia
# 147                     subaru tribeca
# 148                          subaru dl
# 149                          subaru dl
# 150              toyota corona mark ii
# 151                      toyota corona
# 152                toyota corolla 1200
# 153              toyota corona hardtop
# 154           toyota corolla 1600 (sw)
# 155                      toyota carina
# 156                     toyota mark ii
# 157                toyota corolla 1200
# 158                      toyota corona
# 159                     toyota corolla
# 160                      toyota corona
# 161                     toyota corolla
# 162                     toyota mark ii
# 163            toyota corolla liftback
# 164                      toyota corona
# 165          toyota celica gt liftback
# 166              toyota corolla tercel
# 167             toyota corona liftback
# 168                     toyota corolla
# 169                     toyota starlet
# 170                      toyota tercel
# 171                     toyota corolla
# 172                    toyota cressida
# 173                     toyota corolla
# 174                   toyota celica gt
# 175                      toyota corona
# 176                     toyota corolla
# 177                     toyota mark ii
# 178            toyota corolla liftback
# 179                      toyota corona
# 180                     toyota starlet
# 181                     toyouta tercel
# 182                   vokswagen rabbit
# 183       volkswagen 1131 deluxe sedan
# 184               volkswagen model 111
# 185                  volkswagen type 3
# 186                volkswagen 411 (sw)
# 187            volkswagen super beetle
# 188                  volkswagen dasher
# 189                          vw dasher
# 190                          vw rabbit
# 191                  volkswagen rabbit
# 192           volkswagen rabbit custom
# 193                  volkswagen dasher
# 194                    volvo 145e (sw)
# 195                        volvo 144ea
# 196                        volvo 244dl
# 197                          volvo 245
# 198                        volvo 264gl
# 199                       volvo diesel
# 200                    volvo 145e (sw)
# 201                        volvo 144ea
# 202                        volvo 244dl
# 203                          volvo 246
# 204                        volvo 264gl
# Name: CarName, dtype: object

# %%
df['CarBrand'] = df['CarName'].str.split().str[0]

# %%
df = df.drop(columns='CarName',axis=1)

# %%
df['CarBrand'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
df['CarBrand'] = df['CarBrand'].replace({'maxda': 'mazda', 'nissan': 'Nissan', 'porcshce': 'porsche', 
                                         'toyouta': 'toyota', 'vokswagen': 'volkswagen', 'vw': 'volkswagen',
                                         'alfa-romero':'alfa-romeo'})

# %%
ax = df['CarBrand'].value_counts().plot(kind='bar',stacked=True, color = 'blue')

# %%
df.groupby("CarBrand")["price"].mean().sort_values()
# Out:
# CarBrand
# chevrolet      6007.000000
# dodge          7875.444444
# plymouth       7963.428571
# honda          8184.692308
# subaru         8541.250000
# isuzu          8916.500000
# mitsubishi     9239.769231
# renault        9595.000000
# toyota         9885.812500
# volkswagen    10077.500000
# Nissan        10415.666667
# mazda         10652.882353
# saab          15223.333333
# peugeot       15489.090909
# alfa-romeo    15498.333333
# mercury       16503.000000
# audi          17859.166714
# volvo         18063.181818
# bmw           26118.750000
# porsche       31400.500000
# buick         33647.000000
# jaguar        34600.000000
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['CarBrand'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1          3      gas        std        two  convertible        rwd
# 1       2          3      gas        std        two  convertible        rwd
# 2       3          1      gas        std        two    hatchback        rwd
# 3       4          2      gas        std       four        sedan        fwd
# 4       5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
# 1          front       88.6      168.8      64.1       48.8        2548
# 2          front       94.5      171.2      65.5       52.4        2823
# 3          front       99.8      176.6      66.2       54.3        2337
# 4          front       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0       dohc           four         130       mpfi       3.47    2.68
# 1       dohc           four         130       mpfi       3.47    2.68
# 2       ohcv            six         152       mpfi       2.68    3.47
# 3        ohc           four         109       mpfi       3.19    3.40
# 4        ohc           five         136       mpfi       3.19    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# 0               9.0         111     5000       21          27  13495.0
# 1               9.0         111     5000       21          27  16500.0
# 2               9.0         154     5000       19          26  16500.0
# 3              10.0         102     5500       24          30  13950.0
# 4               8.0         115     5500       18          22  17450.0
#
#    CarBrand_alfa-romeo  CarBrand_audi  CarBrand_bmw  CarBrand_buick  \
# 0                 True          False         False           False
# 1                 True          False         False           False
# 2                 True          False         False           False
# 3                False           True         False           False
# 4                False           True         False           False
#
#    CarBrand_chevrolet  CarBrand_dodge  CarBrand_honda  CarBrand_isuzu  \
# 0               False           False           False           False
# 1               False           False           False           False
# 2               False           False           False           False
# 3               False           False           False           False
# 4               False           False           False           False
#
#    CarBrand_jaguar  CarBrand_mazda  CarBrand_mercury  CarBrand_mitsubishi  \
# 0            False           False             False                False
# 1            False           False             False                False
# 2            False           False             False                False
# 3            False           False             False                False
# 4            False           False             False                False
#
#    CarBrand_peugeot  CarBrand_plymouth  CarBrand_porsche  CarBrand_renault  \
# 0             False              False             False             False
# 1             False              False             False             False
# 2             False              False             False             False
# 3             False              False             False             False
# 4             False              False             False             False
#
#    CarBrand_saab  CarBrand_subaru  CarBrand_toyota  CarBrand_volkswagen  \
# 0          False            False            False                False
# 1          False            False            False                False
# 2          False            False            False                False
# 3          False            False            False                False
# 4          False            False            False                False
#
#    CarBrand_volvo
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %% [markdown]
# ### Fuel type

# %%
df['fueltype'].value_counts()
# Out:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
df.groupby("fueltype")["price"].mean()
# Out:
# fueltype
# diesel    15838.1500
# gas       12999.7982
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['fueltype'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling aspiration doornumber      carbody drivewheel  \
# 0       1          3        std        two  convertible        rwd
# 1       2          3        std        two  convertible        rwd
# 2       3          1        std        two    hatchback        rwd
# 3       4          2        std       four        sedan        fwd
# 4       5          2        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
# 1          front       88.6      168.8      64.1       48.8        2548
# 2          front       94.5      171.2      65.5       52.4        2823
# 3          front       99.8      176.6      66.2       54.3        2337
# 4          front       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0       dohc           four         130       mpfi       3.47    2.68
# 1       dohc           four         130       mpfi       3.47    2.68
# 2       ohcv            six         152       mpfi       2.68    3.47
# 3        ohc           four         109       mpfi       3.19    3.40
# 4        ohc           five         136       mpfi       3.19    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# 0               9.0         111     5000       21          27  13495.0
# 1               9.0         111     5000       21          27  16500.0
# 2               9.0         154     5000       19          26  16500.0
# 3              10.0         102     5500       24          30  13950.0
# 4               8.0         115     5500       18          22  17450.0
#
#    CarBrand_alfa-romeo  CarBrand_audi  CarBrand_bmw  CarBrand_buick  \
# 0                 True          False         False           False
# 1                 True          False         False           False
# 2                 True          False         False           False
# 3                False           True         False           False
# 4                False           True         False           False
#
#    CarBrand_chevrolet  CarBrand_dodge  CarBrand_honda  CarBrand_isuzu  \
# 0               False           False           False           False
# 1               False           False           False           False
# 2               False           False           False           False
# 3               False           False           False           False
# 4               False           False           False           False
#
#    CarBrand_jaguar  CarBrand_mazda  CarBrand_mercury  CarBrand_mitsubishi  \
# 0            False           False             False                False
# 1            False           False             False                False
# 2            False           False             False                False
# 3            False           False             False                False
# 4            False           False             False                False
#
#    CarBrand_peugeot  CarBrand_plymouth  CarBrand_porsche  CarBrand_renault  \
# 0             False              False             False             False
# 1             False              False             False             False
# 2             False              False             False             False
# 3             False              False             False             False
# 4             False              False             False             False
#
#    CarBrand_saab  CarBrand_subaru  CarBrand_toyota  CarBrand_volkswagen  \
# 0          False            False            False                False
# 1          False            False            False                False
# 2          False            False            False                False
# 3          False            False            False                False
# 4          False            False            False                False
#
#    CarBrand_volvo  fueltype_gas
# 0           False          True
# 1           False          True
# 2           False          True
# 3           False          True
# 4           False          True

# %% [markdown]
# ### Aspiration

# %%
df.aspiration.value_counts()
# Out:
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %%
df.groupby("aspiration")["price"].mean()
# Out:
# aspiration
# std      12611.270833
# turbo    16298.166676
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['aspiration'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling doornumber      carbody drivewheel enginelocation  \
# 0       1          3        two  convertible        rwd          front
# 1       2          3        two  convertible        rwd          front
# 2       3          1        two    hatchback        rwd          front
# 3       4          2       four        sedan        fwd          front
# 4       5          2       four        sedan        4wd          front
#
#    wheelbase  carlength  carwidth  carheight  curbweight enginetype  \
# 0       88.6      168.8      64.1       48.8        2548       dohc
# 1       88.6      168.8      64.1       48.8        2548       dohc
# 2       94.5      171.2      65.5       52.4        2823       ohcv
# 3       99.8      176.6      66.2       54.3        2337        ohc
# 4       99.4      176.6      66.4       54.3        2824        ohc
#
#   cylindernumber  enginesize fuelsystem  boreratio  stroke  compressionratio  \
# 0           four         130       mpfi       3.47    2.68               9.0
# 1           four         130       mpfi       3.47    2.68               9.0
# 2            six         152       mpfi       2.68    3.47               9.0
# 3           four         109       mpfi       3.19    3.40              10.0
# 4           five         136       mpfi       3.19    3.40               8.0
#
#    horsepower  peakrpm  citympg  highwaympg    price  CarBrand_alfa-romeo  \
# 0         111     5000       21          27  13495.0                 True
# 1         111     5000       21          27  16500.0                 True
# 2         154     5000       19          26  16500.0                 True
# 3         102     5500       24          30  13950.0                False
# 4         115     5500       18          22  17450.0                False
#
#    CarBrand_audi  CarBrand_bmw  CarBrand_buick  CarBrand_chevrolet  \
# 0          False         False           False               False
# 1          False         False           False               False
# 2          False         False           False               False
# 3           True         False           False               False
# 4           True         False           False               False
#
#    CarBrand_dodge  CarBrand_honda  CarBrand_isuzu  CarBrand_jaguar  \
# 0           False           False           False            False
# 1           False           False           False            False
# 2           False           False           False            False
# 3           False           False           False            False
# 4           False           False           False            False
#
#    CarBrand_mazda  CarBrand_mercury  CarBrand_mitsubishi  CarBrand_peugeot  \
# 0           False             False                False             False
# 1           False             False                False             False
# 2           False             False                False             False
# 3           False             False                False             False
# 4           False             False                False             False
#
#    CarBrand_plymouth  CarBrand_porsche  CarBrand_renault  CarBrand_saab  \
# 0              False             False             False          False
# 1              False             False             False          False
# 2              False             False             False          False
# 3              False             False             False          False
# 4              False             False             False          False
#
#    CarBrand_subaru  CarBrand_toyota  CarBrand_volkswagen  CarBrand_volvo  \
# 0            False            False                False           False
# 1            False            False                False           False
# 2            False            False                False           False
# 3            False            False                False           False
# 4            False            False                False           False
#
#    fueltype_gas  aspiration_turbo
# 0          True             False
# 1          True             False
# 2          True             False
# 3          True             False
# 4          True             False

# %% [markdown]
# ### Number of Doors

# %%
df.doornumber.value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %%
df.groupby("doornumber")["price"].mean()
# Out:
# doornumber
# four    13501.152174
# two     12989.924078
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['doornumber'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling      carbody drivewheel enginelocation  wheelbase  \
# 0       1          3  convertible        rwd          front       88.6
# 1       2          3  convertible        rwd          front       88.6
# 2       3          1    hatchback        rwd          front       94.5
# 3       4          2        sedan        fwd          front       99.8
# 4       5          2        sedan        4wd          front       99.4
#
#    carlength  carwidth  carheight  curbweight enginetype cylindernumber  \
# 0      168.8      64.1       48.8        2548       dohc           four
# 1      168.8      64.1       48.8        2548       dohc           four
# 2      171.2      65.5       52.4        2823       ohcv            six
# 3      176.6      66.2       54.3        2337        ohc           four
# 4      176.6      66.4       54.3        2824        ohc           five
#
#    enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# 0         130       mpfi       3.47    2.68               9.0         111
# 1         130       mpfi       3.47    2.68               9.0         111
# 2         152       mpfi       2.68    3.47               9.0         154
# 3         109       mpfi       3.19    3.40              10.0         102
# 4         136       mpfi       3.19    3.40               8.0         115
#
#    peakrpm  citympg  highwaympg    price  CarBrand_alfa-romeo  CarBrand_audi  \
# 0     5000       21          27  13495.0                 True          False
# 1     5000       21          27  16500.0                 True          False
# 2     5000       19          26  16500.0                 True          False
# 3     5500       24          30  13950.0                False           True
# 4     5500       18          22  17450.0                False           True
#
#    CarBrand_bmw  CarBrand_buick  CarBrand_chevrolet  CarBrand_dodge  \
# 0         False           False               False           False
# 1         False           False               False           False
# 2         False           False               False           False
# 3         False           False               False           False
# 4         False           False               False           False
#
#    CarBrand_honda  CarBrand_isuzu  CarBrand_jaguar  CarBrand_mazda  \
# 0           False           False            False           False
# 1           False           False            False           False
# 2           False           False            False           False
# 3           False           False            False           False
# 4           False           False            False           False
#
#    CarBrand_mercury  CarBrand_mitsubishi  CarBrand_peugeot  CarBrand_plymouth  \
# 0             False                False             False              False
# 1             False                False             False              False
# 2             False                False             False              False
# 3             False                False             False              False
# 4             False                False             False              False
#
#    CarBrand_porsche  CarBrand_renault  CarBrand_saab  CarBrand_subaru  \
# 0             False             False          False            False
# 1             False             False          False            False
# 2             False             False          False            False
# 3             False             False          False            False
# 4             False             False          False            False
#
#    CarBrand_toyota  CarBrand_volkswagen  CarBrand_volvo  fueltype_gas  \
# 0            False                False           False          True
# 1            False                False           False          True
# 2            False                False           False          True
# 3            False                False           False          True
# 4            False                False           False          True
#
#    aspiration_turbo  doornumber_two
# 0             False            True
# 1             False            True
# 2             False            True
# 3             False           False
# 4             False           False

# %% [markdown]
# ### Car Body

# %%
df.carbody.value_counts()
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
df.groupby("carbody")["price"].mean().sort_values()
# Out:
# carbody
# hatchback      10376.652386
# wagon          12371.960000
# sedan          14344.270833
# convertible    21890.500000
# hardtop        22208.500000
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['carbody'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling drivewheel enginelocation  wheelbase  carlength  \
# 0       1          3        rwd          front       88.6      168.8
# 1       2          3        rwd          front       88.6      168.8
# 2       3          1        rwd          front       94.5      171.2
# 3       4          2        fwd          front       99.8      176.6
# 4       5          2        4wd          front       99.4      176.6
#
#    carwidth  carheight  curbweight enginetype cylindernumber  enginesize  \
# 0      64.1       48.8        2548       dohc           four         130
# 1      64.1       48.8        2548       dohc           four         130
# 2      65.5       52.4        2823       ohcv            six         152
# 3      66.2       54.3        2337        ohc           four         109
# 4      66.4       54.3        2824        ohc           five         136
#
#   fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0       mpfi       3.47    2.68               9.0         111     5000
# 1       mpfi       3.47    2.68               9.0         111     5000
# 2       mpfi       2.68    3.47               9.0         154     5000
# 3       mpfi       3.19    3.40              10.0         102     5500
# 4       mpfi       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price  CarBrand_alfa-romeo  CarBrand_audi  \
# 0       21          27  13495.0                 True          False
# 1       21          27  16500.0                 True          False
# 2       19          26  16500.0                 True          False
# 3       24          30  13950.0                False           True
# 4       18          22  17450.0                False           True
#
#    CarBrand_bmw  CarBrand_buick  CarBrand_chevrolet  CarBrand_dodge  \
# 0         False           False               False           False
# 1         False           False               False           False
# 2         False           False               False           False
# 3         False           False               False           False
# 4         False           False               False           False
#
#    CarBrand_honda  CarBrand_isuzu  CarBrand_jaguar  CarBrand_mazda  \
# 0           False           False            False           False
# 1           False           False            False           False
# 2           False           False            False           False
# 3           False           False            False           False
# 4           False           False            False           False
#
#    CarBrand_mercury  CarBrand_mitsubishi  CarBrand_peugeot  CarBrand_plymouth  \
# 0             False                False             False              False
# 1             False                False             False              False
# 2             False                False             False              False
# 3             False                False             False              False
# 4             False                False             False              False
#
#    CarBrand_porsche  CarBrand_renault  CarBrand_saab  CarBrand_subaru  \
# 0             False             False          False            False
# 1             False             False          False            False
# 2             False             False          False            False
# 3             False             False          False            False
# 4             False             False          False            False
#
#    CarBrand_toyota  CarBrand_volkswagen  CarBrand_volvo  fueltype_gas  \
# 0            False                False           False          True
# 1            False                False           False          True
# 2            False                False           False          True
# 3            False                False           False          True
# 4            False                False           False          True
#
#    aspiration_turbo  doornumber_two  carbody_hardtop  carbody_hatchback  \
# 0             False            True            False              False
# 1             False            True            False              False
# 2             False            True            False               True
# 3             False           False            False              False
# 4             False           False            False              False
#
#    carbody_sedan  carbody_wagon
# 0          False          False
# 1          False          False
# 2          False          False
# 3           True          False
# 4           True          False

# %% [markdown]
# ### Drive wheel

# %%
df.drivewheel.value_counts()
# Out:
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %%
df.groupby("drivewheel")["price"].mean()
# Out:
# drivewheel
# 4wd    11087.463000
# fwd     9239.308333
# rwd    19910.809211
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['drivewheel'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling enginelocation  wheelbase  carlength  carwidth  \
# 0       1          3          front       88.6      168.8      64.1
# 1       2          3          front       88.6      168.8      64.1
# 2       3          1          front       94.5      171.2      65.5
# 3       4          2          front       99.8      176.6      66.2
# 4       5          2          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price  CarBrand_alfa-romeo  CarBrand_audi  CarBrand_bmw  \
# 0          27  13495.0                 True          False         False
# 1          27  16500.0                 True          False         False
# 2          26  16500.0                 True          False         False
# 3          30  13950.0                False           True         False
# 4          22  17450.0                False           True         False
#
#    CarBrand_buick  CarBrand_chevrolet  CarBrand_dodge  CarBrand_honda  \
# 0           False               False           False           False
# 1           False               False           False           False
# 2           False               False           False           False
# 3           False               False           False           False
# 4           False               False           False           False
#
#    CarBrand_isuzu  CarBrand_jaguar  CarBrand_mazda  CarBrand_mercury  \
# 0           False            False           False             False
# 1           False            False           False             False
# 2           False            False           False             False
# 3           False            False           False             False
# 4           False            False           False             False
#
#    CarBrand_mitsubishi  CarBrand_peugeot  CarBrand_plymouth  CarBrand_porsche  \
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
#
#    CarBrand_renault  CarBrand_saab  CarBrand_subaru  CarBrand_toyota  \
# 0             False          False            False            False
# 1             False          False            False            False
# 2             False          False            False            False
# 3             False          False            False            False
# 4             False          False            False            False
#
#    CarBrand_volkswagen  CarBrand_volvo  fueltype_gas  aspiration_turbo  \
# 0                False           False          True             False
# 1                False           False          True             False
# 2                False           False          True             False
# 3                False           False          True             False
# 4                False           False          True             False
#
#    doornumber_two  carbody_hardtop  carbody_hatchback  carbody_sedan  \
# 0            True            False              False          False
# 1            True            False              False          False
# 2            True            False               True          False
# 3           False            False              False           True
# 4           False            False              False           True
#
#    carbody_wagon  drivewheel_fwd  drivewheel_rwd
# 0          False           False            True
# 1          False           False            True
# 2          False           False            True
# 3          False            True           False
# 4          False           False           False

# %% [markdown]
# ### Engine location

# %%
df.enginelocation.value_counts()
# Out:
# enginelocation
# front    202
# rear       3
# Name: count, dtype: int64

# %%
df.groupby("enginelocation")["price"].mean()
# Out:
# enginelocation
# front    12961.097361
# rear     34528.000000
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['enginelocation'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# 0       dohc           four         130       mpfi       3.47    2.68
# 1       dohc           four         130       mpfi       3.47    2.68
# 2       ohcv            six         152       mpfi       2.68    3.47
# 3        ohc           four         109       mpfi       3.19    3.40
# 4        ohc           five         136       mpfi       3.19    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price  \
# 0               9.0         111     5000       21          27  13495.0
# 1               9.0         111     5000       21          27  16500.0
# 2               9.0         154     5000       19          26  16500.0
# 3              10.0         102     5500       24          30  13950.0
# 4               8.0         115     5500       18          22  17450.0
#
#    CarBrand_alfa-romeo  CarBrand_audi  CarBrand_bmw  CarBrand_buick  \
# 0                 True          False         False           False
# 1                 True          False         False           False
# 2                 True          False         False           False
# 3                False           True         False           False
# 4                False           True         False           False
#
#    CarBrand_chevrolet  CarBrand_dodge  CarBrand_honda  CarBrand_isuzu  \
# 0               False           False           False           False
# 1               False           False           False           False
# 2               False           False           False           False
# 3               False           False           False           False
# 4               False           False           False           False
#
#    CarBrand_jaguar  CarBrand_mazda  CarBrand_mercury  CarBrand_mitsubishi  \
# 0            False           False             False                False
# 1            False           False             False                False
# 2            False           False             False                False
# 3            False           False             False                False
# 4            False           False             False                False
#
#    CarBrand_peugeot  CarBrand_plymouth  CarBrand_porsche  CarBrand_renault  \
# 0             False              False             False             False
# 1             False              False             False             False
# 2             False              False             False             False
# 3             False              False             False             False
# 4             False              False             False             False
#
#    CarBrand_saab  CarBrand_subaru  CarBrand_toyota  CarBrand_volkswagen  \
# 0          False            False            False                False
# 1          False            False            False                False
# 2          False            False            False                False
# 3          False            False            False                False
# 4          False            False            False                False
#
#    CarBrand_volvo  fueltype_gas  aspiration_turbo  doornumber_two  \
# 0           False          True             False            True
# 1           False          True             False            True
# 2           False          True             False            True
# 3           False          True             False           False
# 4           False          True             False           False
#
#    carbody_hardtop  carbody_hatchback  carbody_sedan  carbody_wagon  \
# 0            False              False          False          False
# 1            False              False          False          False
# 2            False               True          False          False
# 3            False              False           True          False
# 4            False              False           True          False
#
#    drivewheel_fwd  drivewheel_rwd  enginelocation_rear
# 0           False            True                False
# 1           False            True                False
# 2           False            True                False
# 3            True           False                False
# 4           False           False                False

# %% [markdown]
# ### Wheel base

# %%
df.wheelbase.describe()
# Out:
# count    205.000000
# mean      98.756585
# std        6.021776
# min       86.600000
# 25%       94.500000
# 50%       97.000000
# 75%      102.400000
# max      120.900000
# Name: wheelbase, dtype: float64

# %%
sns.boxplot(df.wheelbase)
# Out:
# <Axes: >

# %% [markdown]
# ### Car length

# %%
df.carlength.describe()
# Out:
# count    205.000000
# mean     174.049268
# std       12.337289
# min      141.100000
# 25%      166.300000
# 50%      173.200000
# 75%      183.100000
# max      208.100000
# Name: carlength, dtype: float64

# %%
sns.boxplot(df.carlength)
# Out:
# <Axes: >

# %% [markdown]
# correlated

# %% [markdown]
# ### Car width

# %%
df.carwidth.describe()
# Out:
# count    205.000000
# mean      65.907805
# std        2.145204
# min       60.300000
# 25%       64.100000
# 50%       65.500000
# 75%       66.900000
# max       72.300000
# Name: carwidth, dtype: float64

# %%
sns.boxplot(df.carwidth)
# Out:
# <Axes: >

# %% [markdown]
# ### Car height

# %%
df.carheight.describe()
# Out:
# count    205.000000
# mean      53.724878
# std        2.443522
# min       47.800000
# 25%       52.000000
# 50%       54.100000
# 75%       55.500000
# max       59.800000
# Name: carheight, dtype: float64

# %%
sns.boxplot(df.carheight)
# Out:
# <Axes: >

# %% [markdown]
# ### Car weight

# %%
df.curbweight.describe()
# Out:
# count     205.000000
# mean     2555.565854
# std       520.680204
# min      1488.000000
# 25%      2145.000000
# 50%      2414.000000
# 75%      2935.000000
# max      4066.000000
# Name: curbweight, dtype: float64

# %%
sns.boxplot(df.curbweight)
# Out:
# <Axes: >

# %% [markdown]
# ### Engine Type

# %%
df.enginetype.value_counts()
# Out:
# enginetype
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64

# %%
df.groupby("enginetype")["price"].mean().sort_values()
# Out:
# enginetype
# ohc      11574.048426
# rotor    13020.000000
# ohcf     13738.600000
# l        14627.583333
# dohc     18116.416667
# ohcv     25098.384615
# dohcv    31400.500000
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['enginetype'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#   cylindernumber  enginesize fuelsystem  boreratio  stroke  compressionratio  \
# 0           four         130       mpfi       3.47    2.68               9.0
# 1           four         130       mpfi       3.47    2.68               9.0
# 2            six         152       mpfi       2.68    3.47               9.0
# 3           four         109       mpfi       3.19    3.40              10.0
# 4           five         136       mpfi       3.19    3.40               8.0
#
#    horsepower  peakrpm  citympg  highwaympg    price  CarBrand_alfa-romeo  \
# 0         111     5000       21          27  13495.0                 True
# 1         111     5000       21          27  16500.0                 True
# 2         154     5000       19          26  16500.0                 True
# 3         102     5500       24          30  13950.0                False
# 4         115     5500       18          22  17450.0                False
#
#    CarBrand_audi  CarBrand_bmw  CarBrand_buick  CarBrand_chevrolet  \
# 0          False         False           False               False
# 1          False         False           False               False
# 2          False         False           False               False
# 3           True         False           False               False
# 4           True         False           False               False
#
#    CarBrand_dodge  CarBrand_honda  CarBrand_isuzu  CarBrand_jaguar  \
# 0           False           False           False            False
# 1           False           False           False            False
# 2           False           False           False            False
# 3           False           False           False            False
# 4           False           False           False            False
#
#    CarBrand_mazda  CarBrand_mercury  CarBrand_mitsubishi  CarBrand_peugeot  \
# 0           False             False                False             False
# 1           False             False                False             False
# 2           False             False                False             False
# 3           False             False                False             False
# 4           False             False                False             False
#
#    CarBrand_plymouth  CarBrand_porsche  CarBrand_renault  CarBrand_saab  \
# 0              False             False             False          False
# 1              False             False             False          False
# 2              False             False             False          False
# 3              False             False             False          False
# 4              False             False             False          False
#
#    CarBrand_subaru  CarBrand_toyota  CarBrand_volkswagen  CarBrand_volvo  \
# 0            False            False                False           False
# 1            False            False                False           False
# 2            False            False                False           False
# 3            False            False                False           False
# 4            False            False                False           False
#
#    fueltype_gas  aspiration_turbo  doornumber_two  carbody_hardtop  \
# 0          True             False            True            False
# 1          True             False            True            False
# 2          True             False            True            False
# 3          True             False           False            False
# 4          True             False           False            False
#
#    carbody_hatchback  carbody_sedan  carbody_wagon  drivewheel_fwd  \
# 0              False          False          False           False
# 1              False          False          False           False
# 2               True          False          False           False
# 3              False           True          False            True
# 4              False           True          False           False
#
#    drivewheel_rwd  enginelocation_rear  enginetype_dohcv  enginetype_l  \
# 0            True                False             False         False
# 1            True                False             False         False
# 2            True                False             False         False
# 3           False                False             False         False
# 4           False                False             False         False
#
#    enginetype_ohc  enginetype_ohcf  enginetype_ohcv  enginetype_rotor
# 0           False            False            False             False
# 1           False            False            False             False
# 2           False            False             True             False
# 3            True            False            False             False
# 4            True            False            False             False

# %% [markdown]
# ### Cylinder number

# %%
df.cylindernumber.value_counts()
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: count, dtype: int64

# %%
df.groupby("cylindernumber")["price"].mean().sort_values()
# Out:
# cylindernumber
# three      5151.000000
# four      10285.754717
# two       13020.000000
# five      21630.469727
# six       23671.833333
# twelve    36000.000000
# eight     37400.100000
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['cylindernumber'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# 0         130       mpfi       3.47    2.68               9.0         111
# 1         130       mpfi       3.47    2.68               9.0         111
# 2         152       mpfi       2.68    3.47               9.0         154
# 3         109       mpfi       3.19    3.40              10.0         102
# 4         136       mpfi       3.19    3.40               8.0         115
#
#    peakrpm  citympg  highwaympg    price  CarBrand_alfa-romeo  CarBrand_audi  \
# 0     5000       21          27  13495.0                 True          False
# 1     5000       21          27  16500.0                 True          False
# 2     5000       19          26  16500.0                 True          False
# 3     5500       24          30  13950.0                False           True
# 4     5500       18          22  17450.0                False           True
#
#    CarBrand_bmw  CarBrand_buick  CarBrand_chevrolet  CarBrand_dodge  \
# 0         False           False               False           False
# 1         False           False               False           False
# 2         False           False               False           False
# 3         False           False               False           False
# 4         False           False               False           False
#
#    CarBrand_honda  CarBrand_isuzu  CarBrand_jaguar  CarBrand_mazda  \
# 0           False           False            False           False
# 1           False           False            False           False
# 2           False           False            False           False
# 3           False           False            False           False
# 4           False           False            False           False
#
#    CarBrand_mercury  CarBrand_mitsubishi  CarBrand_peugeot  CarBrand_plymouth  \
# 0             False                False             False              False
# 1             False                False             False              False
# 2             False                False             False              False
# 3             False                False             False              False
# 4             False                False             False              False
#
#    CarBrand_porsche  CarBrand_renault  CarBrand_saab  CarBrand_subaru  \
# 0             False             False          False            False
# 1             False             False          False            False
# 2             False             False          False            False
# 3             False             False          False            False
# 4             False             False          False            False
#
#    CarBrand_toyota  CarBrand_volkswagen  CarBrand_volvo  fueltype_gas  \
# 0            False                False           False          True
# 1            False                False           False          True
# 2            False                False           False          True
# 3            False                False           False          True
# 4            False                False           False          True
#
#    aspiration_turbo  doornumber_two  carbody_hardtop  carbody_hatchback  \
# 0             False            True            False              False
# 1             False            True            False              False
# 2             False            True            False               True
# 3             False           False            False              False
# 4             False           False            False              False
#
#    carbody_sedan  carbody_wagon  drivewheel_fwd  drivewheel_rwd  \
# 0          False          False           False            True
# 1          False          False           False            True
# 2          False          False           False            True
# 3           True          False            True           False
# 4           True          False           False           False
#
#    enginelocation_rear  enginetype_dohcv  enginetype_l  enginetype_ohc  \
# 0                False             False         False           False
# 1                False             False         False           False
# 2                False             False         False           False
# 3                False             False         False            True
# 4                False             False         False            True
#
#    enginetype_ohcf  enginetype_ohcv  enginetype_rotor  cylindernumber_five  \
# 0            False            False             False                False
# 1            False            False             False                False
# 2            False             True             False                False
# 3            False            False             False                False
# 4            False            False             False                 True
#
#    cylindernumber_four  cylindernumber_six  cylindernumber_three  \
# 0                 True               False                 False
# 1                 True               False                 False
# 2                False                True                 False
# 3                 True               False                 False
# 4                False               False                 False
#
#    cylindernumber_twelve  cylindernumber_two
# 0                  False               False
# 1                  False               False
# 2                  False               False
# 3                  False               False
# 4                  False               False

# %% [markdown]
# ### Engine size

# %%
df.enginesize.describe()
# Out:
# count    205.000000
# mean     126.907317
# std       41.642693
# min       61.000000
# 25%       97.000000
# 50%      120.000000
# 75%      141.000000
# max      326.000000
# Name: enginesize, dtype: float64

# %%
sns.boxplot(df.enginesize)
# Out:
# <Axes: >

# %% [markdown]
# ### Fuel system

# %%
df.fuelsystem.value_counts()
# Out:
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
df.groupby("fuelsystem")["price"].mean().sort_values()
# Out:
# fuelsystem
# 2bbl     7478.151515
# 1bbl     7555.545455
# spdi    10990.444444
# spfi    11048.000000
# 4bbl    12145.000000
# mfi     12964.000000
# idi     15838.150000
# mpfi    17754.602840
# Name: price, dtype: float64

# %%
df = pd.get_dummies(df, columns=['fuelsystem'], drop_first=True)
df.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price  CarBrand_alfa-romeo  CarBrand_audi  \
# 0       21          27  13495.0                 True          False
# 1       21          27  16500.0                 True          False
# 2       19          26  16500.0                 True          False
# 3       24          30  13950.0                False           True
# 4       18          22  17450.0                False           True
#
#    CarBrand_bmw  CarBrand_buick  CarBrand_chevrolet  CarBrand_dodge  \
# 0         False           False               False           False
# 1         False           False               False           False
# 2         False           False               False           False
# 3         False           False               False           False
# 4         False           False               False           False
#
#    CarBrand_honda  CarBrand_isuzu  CarBrand_jaguar  CarBrand_mazda  \
# 0           False           False            False           False
# 1           False           False            False           False
# 2           False           False            False           False
# 3           False           False            False           False
# 4           False           False            False           False
#
#    CarBrand_mercury  CarBrand_mitsubishi  CarBrand_peugeot  CarBrand_plymouth  \
# 0             False                False             False              False
# 1             False                False             False              False
# 2             False                False             False              False
# 3             False                False             False              False
# 4             False                False             False              False
#
#    CarBrand_porsche  CarBrand_renault  CarBrand_saab  CarBrand_subaru  \
# 0             False             False          False            False
# 1             False             False          False            False
# 2             False             False          False            False
# 3             False             False          False            False
# 4             False             False          False            False
#
#    CarBrand_toyota  CarBrand_volkswagen  CarBrand_volvo  fueltype_gas  \
# 0            False                False           False          True
# 1            False                False           False          True
# 2            False                False           False          True
# 3            False                False           False          True
# 4            False                False           False          True
#
#    aspiration_turbo  doornumber_two  carbody_hardtop  carbody_hatchback  \
# 0             False            True            False              False
# 1             False            True            False              False
# 2             False            True            False               True
# 3             False           False            False              False
# 4             False           False            False              False
#
#    carbody_sedan  carbody_wagon  drivewheel_fwd  drivewheel_rwd  \
# 0          False          False           False            True
# 1          False          False           False            True
# 2          False          False           False            True
# 3           True          False            True           False
# 4           True          False           False           False
#
#    enginelocation_rear  enginetype_dohcv  enginetype_l  enginetype_ohc  \
# 0                False             False         False           False
# 1                False             False         False           False
# 2                False             False         False           False
# 3                False             False         False            True
# 4                False             False         False            True
#
#    enginetype_ohcf  enginetype_ohcv  enginetype_rotor  cylindernumber_five  \
# 0            False            False             False                False
# 1            False            False             False                False
# 2            False             True             False                False
# 3            False            False             False                False
# 4            False            False             False                 True
#
#    cylindernumber_four  cylindernumber_six  cylindernumber_three  \
# 0                 True               False                 False
# 1                 True               False                 False
# 2                False                True                 False
# 3                 True               False                 False
# 4                False               False                 False
#
#    cylindernumber_twelve  cylindernumber_two  fuelsystem_2bbl  \
# 0                  False               False            False
# 1                  False               False            False
# 2                  False               False            False
# 3                  False               False            False
# 4                  False               False            False
#
#    fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mfi  fuelsystem_mpfi  \
# 0            False           False           False             True
# 1            False           False           False             True
# 2            False           False           False             True
# 3            False           False           False             True
# 4            False           False           False             True
#
#    fuelsystem_spdi  fuelsystem_spfi
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False

# %% [markdown]
# ### Bore Ratio

# %%
df.boreratio.describe()
# Out:
# count    205.000000
# mean       3.329756
# std        0.270844
# min        2.540000
# 25%        3.150000
# 50%        3.310000
# 75%        3.580000
# max        3.940000
# Name: boreratio, dtype: float64

# %%
sns.boxplot(df.boreratio)
# Out:
# <Axes: >

# %% [markdown]
# ### Stroke

# %%
df.stroke.describe()
# Out:
# count    205.000000
# mean       3.255415
# std        0.313597
# min        2.070000
# 25%        3.110000
# 50%        3.290000
# 75%        3.410000
# max        4.170000
# Name: stroke, dtype: float64

# %%
sns.boxplot(df.stroke)
# Out:
# <Axes: >

# %% [markdown]
# ### Compression Ratio

# %%
df.compressionratio.describe()
# Out:
# count    205.000000
# mean      10.142537
# std        3.972040
# min        7.000000
# 25%        8.600000
# 50%        9.000000
# 75%        9.400000
# max       23.000000
# Name: compressionratio, dtype: float64

# %%
sns.boxplot(df.compressionratio)
# Out:
# <Axes: >

# %% [markdown]
# ### Horse power

# %%
df.horsepower.describe()
# Out:
# count    205.000000
# mean     104.117073
# std       39.544167
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      288.000000
# Name: horsepower, dtype: float64

# %%
sns.boxplot(df.horsepower)
# Out:
# <Axes: >

# %% [markdown]
# ### Peak RPM

# %%
df.peakrpm.describe()
# Out:
# count     205.000000
# mean     5125.121951
# std       476.985643
# min      4150.000000
# 25%      4800.000000
# 50%      5200.000000
# 75%      5500.000000
# max      6600.000000
# Name: peakrpm, dtype: float64

# %%
sns.boxplot(df.peakrpm)
# Out:
# <Axes: >

# %% [markdown]
# ### City Mileage

# %%
df.citympg.describe()
# Out:
# count    205.000000
# mean      25.219512
# std        6.542142
# min       13.000000
# 25%       19.000000
# 50%       24.000000
# 75%       30.000000
# max       49.000000
# Name: citympg, dtype: float64

# %%
sns.boxplot(df.citympg)
# Out:
# <Axes: >

# %% [markdown]
# ### Highway Mileage

# %%
df.highwaympg.describe()
# Out:
# count    205.000000
# mean      30.751220
# std        6.886443
# min       16.000000
# 25%       25.000000
# 50%       30.000000
# 75%       34.000000
# max       54.000000
# Name: highwaympg, dtype: float64

# %%
sns.boxplot(df.highwaympg)
# Out:
# <Axes: >

# %% [markdown]
# ## Correlation

# %%
numerical_features = ['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
                      'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
                      'peakrpm', 'citympg', 'highwaympg', 'price']

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df[numerical_features].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#sns.pairplot(df)

# %% [markdown]
# ## Model

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'CarBrand_alfa-romeo', 'CarBrand_audi', 'CarBrand_bmw',
#        'CarBrand_buick', 'CarBrand_chevrolet', 'CarBrand_dodge',
#        'CarBrand_honda', 'CarBrand_isuzu', 'CarBrand_jaguar', 'CarBrand_mazda',
#        'CarBrand_mercury', 'CarBrand_mitsubishi', 'CarBrand_peugeot',
#        'CarBrand_plymouth', 'CarBrand_porsche', 'CarBrand_renault',
#        'CarBrand_saab', 'CarBrand_subaru', 'CarBrand_toyota',
#        'CarBrand_volkswagen', 'CarBrand_volvo', 'fueltype_gas',
#        'aspiration_turbo', 'doornumber_two', 'carbody_hardtop',
#        'carbody_hatchback', 'carbody_sedan', 'carbody_wagon', 'drivewheel_fwd',
#        'drivewheel_rwd', 'enginelocation_rear', 'enginetype_dohcv',
#        'enginetype_l', 'enginetype_ohc', 'enginetype_ohcf', 'enginetype_ohcv',
#        'enginetype_rotor', 'cylindernumber_five', 'cylindernumber_four',
#        'cylindernumber_six', 'cylindernumber_three', 'cylindernumber_twelve',
#        'cylindernumber_two', 'fuelsystem_2bbl', 'fuelsystem_4bbl',
#        'fuelsystem_idi', 'fuelsystem_mfi', 'fuelsystem_mpfi',
#        'fuelsystem_spdi', 'fuelsystem_spfi'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Splitting the dataset
X = df.drop(['price'], axis=1)
y = df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
pred = model.predict(X_test)

pred_train = model.predict(X_train)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("MAE: ", (mean_absolute_error(pred, y_test)))
print("MSE: ", (mean_squared_error(pred, y_test)))
print("MSE on training data: ", (mean_squared_error(pred_train, y_train)))
print("R2 score: ", (r2_score(pred, y_test)))

sns.regplot(x=pred, y=y_test)
plt.xlabel("Predicted Price")
plt.ylabel('Actual Price')
plt.title("Actual vs predicted price")
plt.show()
# Out:
# MAE:  1838.294739844563
# MSE:  5588133.924538797
# MSE on training data:  2000306.9231106401
# R2 score:  0.9435909294079156

# %%
pred_df=pd.DataFrame({'Actual Value':y_test,'Predicted Value':pred,'Difference':y_test-pred})
pred_df
# Out:
#      Actual Value  Predicted Value   Difference
# 15      30760.000     32279.774888 -1519.774888
# 9       17859.167     23390.161741 -5530.994741
# 100      9549.000     11719.533136 -2170.533136
# 132     11850.000     12948.494852 -1098.494852
# 68      28248.000     28351.326516  -103.326516
# 95       7799.000      6937.361167   861.638833
# 159      7788.000      7122.972657   665.027343
# 162      9258.000      7665.893731  1592.106269
# 147     10198.000      8407.167010  1790.832990
# 182      7775.000      8246.636912  -471.636912
# 191     13295.000     11842.928277  1452.071723
# 164      8238.000      7049.535161  1188.464839
# 65      18280.000     14279.827993  4000.172007
# 175      9988.000      9438.713643   549.286357
# 73      40960.000     42903.218164 -1943.218164
# 152      6488.000      5463.268797  1024.731203
# 18       5151.000      -424.657340  5575.657340
# 82      12629.000     13554.380524  -925.380524
# 86       8189.000      9279.561140 -1090.561140
# 143      9960.000      8081.044830  1878.955170
# 60       8495.000     11666.324588 -3171.324588
